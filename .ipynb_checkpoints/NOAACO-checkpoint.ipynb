# %%
# Dependencies and Setup
# %matplotlib notebook
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from citipy import citipy

#import csv
weather_path='2550762.csv'
weatherdata=pd.read_csv(weather_path)
#print(weatherdata.dtypes)
weatherdata.head(20)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-5ca96d36979b> in <module>
#      10 #import csv
#      11 weather_path='2550762.csv'
# ---> 12 weatherdata=pd.read_csv(weather_path)
#      13 #print(weatherdata.dtypes)
#      14 weatherdata.head(20)
#
# ...

# %%
#summarize data
weatherdescribe=weatherdata.describe()
weatherdescribe

# %%
weatherstat=weatherdata.groupby(["DATE"])
weather1=weatherstat.mean()
weather1

# %%
weather1.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-ee25b29300f4> in <module>
# ----> 1 weather1.columns
#
# NameError: name 'weather1' is not defined

# %%
weather1
# Out:
#            AWND        CDSD        DSND       DSNW       EMNT       EMSD  \
# DATE
# 2015  22.300000  311.326087  141.975000  24.240000  -7.739130  32.975000
# 2016  14.533333  317.260870  133.878049  22.481481 -11.000000  38.414634
# 2017   8.950000  337.521739  124.951220  20.666667 -11.765957  32.536585
# 2018   9.200000  390.895833  119.311111  20.000000  -6.367347  24.177778
# 2019   8.800000  345.403846  151.127660  30.354839 -10.754717  41.021277
# 2020   9.400000  368.117647  126.979592  21.166667 -10.333333  30.836735
#
#            EMSN      EMXP       EMXT         HDSD  ...       TAVG       TMAX  \
# DATE                                               ...
# 2015   9.196000  1.513175  87.000000  7548.040816  ...  44.932609  57.650000
# 2016  11.677778  1.366056  89.702128  7781.520833  ...  44.859574  57.902128
# 2017   9.113333  1.507639  88.895833  7220.113636  ...  46.093617  59.254167
# 2018   6.974194  1.269306  89.877551  7170.020833  ...  45.189583  58.406122
# ...

# %%
index=weather1.index
index
# Out:
# Int64Index([2015, 2016, 2017, 2018, 2019, 2020], dtype='int64', name='DATE')

# %%
precip1=weatherdata[['DATE', 'PRCP']]
precip1=precip.dropna()

precip2=precip1.groupby(["DATE"])
precip=precip2.mean()
precip
# Out:
#            PRCP
# DATE
# 2015  23.617286
# 2016  19.192778
# 2017  20.588243
# 2018  16.454800
# 2019  21.325325
# 2020  14.161463

# %%
x_axis=index
y_axis=weather1['PRCP']
plt.bar(x_axis, y_axis, color='azure', edgecolor='blue', alpha=0.5, align='center')
plt.xlabel('Year')
plt.ylabel('Precip in Inches')
plt.title('Number of Annual Precip by Year in Colorado')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-342ffbde94a5> in <module>
# ----> 1 x_axis=index
#       2 y_axis=weather1['PRCP']
#       3 plt.bar(x_axis, y_axis, color='azure', edgecolor='blue', alpha=0.5, align='center')
#       4 plt.xlabel('Year')
#       5 plt.ylabel('Precip in Inches')
#
# NameError: name 'index' is not defined
